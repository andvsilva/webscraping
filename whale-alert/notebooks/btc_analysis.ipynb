# %%
import pandas as pd

# %%
database_txo = pd.read_csv('../dataset/database_txo_btc.csv')
database_txo
# Out:
#    blockchain  amount_coin   amount_usd  \
# 0         BTC   208.038060   8433485.00
# 1         BTC    17.647198    710611.06
# 2         BTC    17.686884    712209.10
# 3         BTC    34.498154   1389159.20
# 4         BTC    66.734460   2712317.50
# 5         BTC    19.899600    807651.30
# 6         BTC   252.941910  10281376.00
# 7         BTC   152.845030   6173124.00
# 8         BTC    27.517843   1114631.60
# 9         BTC    59.999360   2439001.00
# 10        BTC    23.445711    949062.30
# 11        BTC    76.402970   3092726.80
# 12        BTC    75.777080   3089192.50
#
#                                                  hash            from_to  \
# 0   7fb5628921718446500602cfab0fdb5b704741b0fbe274...  exchange-exchange
# 1                                     Multiple Hashes    unknown-unknown
# 2   202ca8f94a0f1b34809742355d477f34db1ab57e8c2537...    unknown-unknown
# 3   fe5c35effc83f3e9670b885e1d1cf92615a95c9d191013...  exchange-exchange
# 4   4880c24733d70c1b3c7ef3003b1d9d9779b69c6213508b...    unknown-unknown
# 5   e3c2ac76c82ec7190d2fb4bb2b5198cfdddd55bdb310c8...   exchange-unknown
# 6   c6dba22a4cbc8645a1ec80265bc62e024669b6f8b243ba...                NaN
# 7   f7feb682a5f9323da9bee6582544ebeddc5ded482d53a7...    unknown-unknown
# 8   f93a1abd9ee8515582249cc9940af369d0b9c15d81bf2c...    unknown-unknown
# 9   303de98b03a6336dac4b0c31a1d22e6b3247b4313cc397...    unknown-unknown
# 10                                    Multiple Hashes    unknown-unknown
# 11  c7422c89f4c9e1fc4962e47bc29d7ca7fb99acc09fb9cf...    unknown-unknown
# 12  820f73bdca97a6d51bcbeecb3a3c54200a28f03dc4473c...    unknown-unknown
#
#               id                 date     price  change24h_pct
# 0   1.831896e+09  2022-04-21 20:51:58  40535.09          -2.04
# 1   1.831903e+09  2022-04-21 21:07:00  40435.25          -2.56
# 2   1.831902e+09  2022-04-21 21:07:39  40451.85          -2.49
# 3   1.831903e+09  2022-04-21 21:09:07  40451.85          -2.49
# 4   1.831907e+09  2022-04-21 21:26:25  40632.54          -2.11
# 5   1.831910e+09  2022-04-21 21:33:45  40504.71          -2.47
# 6            NaN                  NaN       NaN            NaN
# 7   1.831912e+09  2022-04-21 21:41:47  40378.84          -2.83
# 8   1.831915e+09  2022-04-21 21:52:34  40446.45          -2.73
# 9   1.831916e+09  2022-04-21 21:54:22  40434.43          -2.71
# 10  1.831922e+09  2022-04-21 22:13:00  40450.32          -2.55
# 11  1.831919e+09  2022-04-21 22:13:33  40348.43          -2.80
# 12  1.831922e+09  2022-04-21 22:17:22  40339.32          -2.95

# %%
# Looking for NaN on the dataset.
# counting the number of NaN for each feature.
database_txo.isna().sum()
# Out:
# blockchain       0
# amount_coin      0
# amount_usd       0
# hash             0
# from_to          1
# id               1
# date             1
# price            1
# change24h_pct    1
# dtype: int64

# %%
database_txo =  database_txo.dropna()
database_txo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12 entries, 0 to 12
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   blockchain     12 non-null     object
#  1   amount_coin    12 non-null     float64
#  2   amount_usd     12 non-null     float64
#  3   hash           12 non-null     object
#  4   from_to        12 non-null     object
#  5   id             12 non-null     float64
#  6   date           12 non-null     object
#  7   price          12 non-null     float64
#  8   change24h_pct  12 non-null     float64
# dtypes: float64(5), object(4)
# memory usage: 960.0+ bytes

# %%
database_txo.isna().sum()
# Out:
# blockchain       0
# amount_coin      0
# amount_usd       0
# hash             0
# from_to          0
# id               0
# date             0
# price            0
# change24h_pct    0
# dtype: int64

# %%
database_txo['from_to'] = database_txo['from_to'].astype('string')
database_txo['blockchain'] = database_txo['blockchain'].astype('string')
database_txo['hash'] = database_txo['hash'].astype('string')
database_txo['date'] = database_txo['date'].astype('datetime64[ns]')
# Out:
# /tmp/ipykernel_172601/722664305.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   database_txo['from_to'] = database_txo['from_to'].astype('string')
# /tmp/ipykernel_172601/722664305.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   database_txo['blockchain'] = database_txo['blockchain'].astype('string')
# /tmp/ipykernel_172601/722664305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   database_txo['hash'] = database_txo['hash'].astype('string')
# /tmp/ipykernel_172601/722664305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   database_txo['date'] = database_txo['date'].astype('datetime64[ns]')

# %%
database_txo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12 entries, 0 to 12
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   blockchain     12 non-null     string
#  1   amount_coin    12 non-null     float64
#  2   amount_usd     12 non-null     float64
#  3   hash           12 non-null     string
#  4   from_to        12 non-null     string
#  5   id             12 non-null     float64
#  6   date           12 non-null     datetime64[ns]
#  7   price          12 non-null     float64
#  8   change24h_pct  12 non-null     float64
# dtypes: datetime64[ns](1), float64(5), string(3)
# memory usage: 960.0 bytes

# %%
df_amount_usd_fromto = database_txo.drop(columns=['blockchain','hash','id'])
df_amount_usd_fromto
# Out:
#     amount_coin  amount_usd            from_to                date     price  \
# 0    208.038060  8433485.00  exchange-exchange 2022-04-21 20:51:58  40535.09
# 1     17.647198   710611.06    unknown-unknown 2022-04-21 21:07:00  40435.25
# 2     17.686884   712209.10    unknown-unknown 2022-04-21 21:07:39  40451.85
# 3     34.498154  1389159.20  exchange-exchange 2022-04-21 21:09:07  40451.85
# 4     66.734460  2712317.50    unknown-unknown 2022-04-21 21:26:25  40632.54
# 5     19.899600   807651.30   exchange-unknown 2022-04-21 21:33:45  40504.71
# 7    152.845030  6173124.00    unknown-unknown 2022-04-21 21:41:47  40378.84
# 8     27.517843  1114631.60    unknown-unknown 2022-04-21 21:52:34  40446.45
# 9     59.999360  2439001.00    unknown-unknown 2022-04-21 21:54:22  40434.43
# 10    23.445711   949062.30    unknown-unknown 2022-04-21 22:13:00  40450.32
# 11    76.402970  3092726.80    unknown-unknown 2022-04-21 22:13:33  40348.43
# 12    75.777080  3089192.50    unknown-unknown 2022-04-21 22:17:22  40339.32
#
#     change24h_pct
# 0           -2.04
# 1           -2.56
# 2           -2.49
# 3           -2.49
# 4           -2.11
# 5           -2.47
# 7           -2.83
# 8           -2.73
# 9           -2.71
# 10          -2.55
# 11          -2.80
# 12          -2.95

# %%
from_tos = list(df_amount_usd_fromto['from_to'].unique())

for ifrom_to in from_tos:
    df_amount_coin = df_amount_usd_fromto[['amount_coin','date']].loc[df_amount_usd_fromto['from_to'] == f'{ifrom_to}']
    df_amount_usd = df_amount_usd_fromto[['amount_usd','date']].loc[df_amount_usd_fromto['from_to'] == f'{ifrom_to}']
    amount_coin = dict(df_amount_coin.max())
    amount_usd = dict(df_amount_usd.max())
    coins = amount_coin['amount_coin']
    txo_coins_date = amount_coin['date']
    usds = amount_usd['amount_usd']
    print(f'txo: {ifrom_to} -> maximum amount:  {coins} BTC ($ {usds}) USD - date: {txo_coins_date})')
# Out:
# txo: exchange-exchange -> maximum amount:  208.03806 BTC ($ 8433485.0) USD - date: 2022-04-21 21:09:07)
# txo: unknown-unknown -> maximum amount:  152.84503 BTC ($ 6173124.0) USD - date: 2022-04-21 22:17:22)
# txo: exchange-unknown -> maximum amount:  19.8996 BTC ($ 807651.3) USD - date: 2022-04-21 21:33:45)

# %%
#import os
#from whalealert.whalealert import WhaleAlert
#import time
#
#whale = WhaleAlert()

# %%
#api_key = os.environ['api_key_whale']
#transaction_count_limit = 1
#start_time = int(time.time() - 600)
#success, transactions, status = whale.get_transactions(start_time, api_key=api_key, limit=transaction_count_limit)
#transactions
