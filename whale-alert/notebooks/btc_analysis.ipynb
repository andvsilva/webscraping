# %%
import pandas as pd

# %%
database_txo = pd.read_csv('../dataset/database_txo_btc.csv')
database_txo
# Out:
#     blockchain  amount_coin  amount_usd  \
# 0          BTC   208.038060  8433485.00
# 1          BTC    17.647198   710611.06
# 2          BTC    17.686884   712209.10
# 3          BTC    34.498154  1389159.20
# 4          BTC    66.734460  2712317.50
# ..         ...          ...         ...
# 137        BTC    44.000000  1753593.50
# 138        BTC    65.393670  2603490.80
# 139        BTC    66.201790  2612299.50
# 140        BTC    24.999600   997488.25
# 141        BTC    29.999500  1185847.20
#
#                                                   hash            from_to  \
# 0    7fb5628921718446500602cfab0fdb5b704741b0fbe274...  exchange-exchange
# 1                                      Multiple Hashes    unknown-unknown
# 2    202ca8f94a0f1b34809742355d477f34db1ab57e8c2537...    unknown-unknown
# 3    fe5c35effc83f3e9670b885e1d1cf92615a95c9d191013...  exchange-exchange
# 4    4880c24733d70c1b3c7ef3003b1d9d9779b69c6213508b...    unknown-unknown
# ..                                                 ...                ...
# 137  044bf6f8b6edb998f9f2aa6d9392d4e6f5fbc6409cfaef...    unknown-unknown
# 138  4aad29d0cb0d36322bc0a50cab902e67f5d9d61ec20176...    unknown-unknown
# 139  6c907a9047c2c72ca51550b32654e07728af1bbd3fa843...    unknown-unknown
# 140  4fff6ca6bc42efefde08682f0ae7582aabac49ea1e146c...   exchange-unknown
# 141  42b29c1d210f08dcc46d3f6e4ea613e0481e7eb193c667...                NaN
#
#                id                 date     price  change24h_pct
# 0    1.831896e+09  2022-04-21 20:51:58  40535.09          -2.04
# 1    1.831903e+09  2022-04-21 21:07:00  40435.25          -2.56
# 2    1.831902e+09  2022-04-21 21:07:39  40451.85          -2.49
# 3    1.831903e+09  2022-04-21 21:09:07  40451.85          -2.49
# 4    1.831907e+09  2022-04-21 21:26:25  40632.54          -2.11
# ..            ...                  ...       ...            ...
# 137  1.832370e+09  2022-04-22 18:41:47  39606.60          -2.83
# 138  1.832375e+09  2022-04-22 19:09:04  39713.47          -2.58
# 139  1.832379e+09  2022-04-22 19:21:37  39669.27          -2.36
# 140  1.832383e+09  2022-04-22 19:37:11  39730.82          -1.57
# 141           NaN                  NaN       NaN            NaN
#
# [142 rows x 9 columns]

# %%
# Looking for NaN on the dataset.
# counting the number of NaN for each feature.
database_txo.isna().sum()
# Out:
# blockchain       0
# amount_coin      0
# amount_usd       0
# hash             0
# from_to          8
# id               8
# date             8
# price            8
# change24h_pct    8
# dtype: int64

# %%
database_txo =  database_txo.dropna()
database_txo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 134 entries, 0 to 140
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   blockchain     134 non-null    object
#  1   amount_coin    134 non-null    float64
#  2   amount_usd     134 non-null    float64
#  3   hash           134 non-null    object
#  4   from_to        134 non-null    object
#  5   id             134 non-null    float64
#  6   date           134 non-null    object
#  7   price          134 non-null    float64
#  8   change24h_pct  134 non-null    float64
# dtypes: float64(5), object(4)
# memory usage: 10.5+ KB

# %%
database_txo.isna().sum()
# Out:
# blockchain       0
# amount_coin      0
# amount_usd       0
# hash             0
# from_to          0
# id               0
# date             0
# price            0
# change24h_pct    0
# dtype: int64

# %%
database_txo['from_to'] = database_txo['from_to'].astype('string')
database_txo['blockchain'] = database_txo['blockchain'].astype('string')
database_txo['hash'] = database_txo['hash'].astype('string')
database_txo['date'] = database_txo['date'].astype('datetime64[ns]')
# Out:
# /tmp/ipykernel_276947/722664305.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   database_txo['from_to'] = database_txo['from_to'].astype('string')
# /tmp/ipykernel_276947/722664305.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   database_txo['blockchain'] = database_txo['blockchain'].astype('string')
# /tmp/ipykernel_276947/722664305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   database_txo['hash'] = database_txo['hash'].astype('string')
# /tmp/ipykernel_276947/722664305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   database_txo['date'] = database_txo['date'].astype('datetime64[ns]')

# %%
database_txo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 134 entries, 0 to 140
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   blockchain     134 non-null    string
#  1   amount_coin    134 non-null    float64
#  2   amount_usd     134 non-null    float64
#  3   hash           134 non-null    string
#  4   from_to        134 non-null    string
#  5   id             134 non-null    float64
#  6   date           134 non-null    datetime64[ns]
#  7   price          134 non-null    float64
#  8   change24h_pct  134 non-null    float64
# dtypes: datetime64[ns](1), float64(5), string(3)
# memory usage: 10.5 KB

# %%
df_amount_usd_fromto = database_txo.drop(columns=['blockchain','hash','id'])
df_amount_usd_fromto
# Out:
#      amount_coin  amount_usd            from_to                date     price  \
# 0     208.038060  8433485.00  exchange-exchange 2022-04-21 20:51:58  40535.09
# 1      17.647198   710611.06    unknown-unknown 2022-04-21 21:07:00  40435.25
# 2      17.686884   712209.10    unknown-unknown 2022-04-21 21:07:39  40451.85
# 3      34.498154  1389159.20  exchange-exchange 2022-04-21 21:09:07  40451.85
# 4      66.734460  2712317.50    unknown-unknown 2022-04-21 21:26:25  40632.54
# ..           ...         ...                ...                 ...       ...
# 135    58.591550  2321062.80  exchange-exchange 2022-04-22 18:30:07  39630.55
# 137    44.000000  1753593.50    unknown-unknown 2022-04-22 18:41:47  39606.60
# 138    65.393670  2603490.80    unknown-unknown 2022-04-22 19:09:04  39713.47
# 139    66.201790  2612299.50    unknown-unknown 2022-04-22 19:21:37  39669.27
# 140    24.999600   997488.25   exchange-unknown 2022-04-22 19:37:11  39730.82
#
#      change24h_pct
# 0            -2.04
# 1            -2.56
# 2            -2.49
# 3            -2.49
# 4            -2.11
# ..             ...
# 135          -2.88
# 137          -2.83
# 138          -2.58
# 139          -2.36
# 140          -1.57
#
# [134 rows x 6 columns]

# %%
from_tos = list(df_amount_usd_fromto['from_to'].unique())

for ifrom_to in from_tos:
    df_amount_coin = df_amount_usd_fromto[['amount_coin','date']].loc[df_amount_usd_fromto['from_to'] == f'{ifrom_to}']
    df_amount_usd = df_amount_usd_fromto[['amount_usd','date']].loc[df_amount_usd_fromto['from_to'] == f'{ifrom_to}']
    amount_coin = dict(df_amount_coin.max())
    amount_usd = dict(df_amount_usd.max())
    coins = amount_coin['amount_coin']
    txo_coins_date = amount_coin['date']
    usds = amount_usd['amount_usd']
    print(f'txo: {ifrom_to} -> maximum amount:  {coins} BTC ($ {usds}) USD - date: {txo_coins_date})')
# Out:
# txo: exchange-exchange -> maximum amount:  383.98856 BTC ($ 15149524.0) USD - date: 2022-04-22 18:30:07)
# txo: unknown-unknown -> maximum amount:  2500.7043 BTC ($ 101850024.0) USD - date: 2022-04-22 19:21:37)
# txo: exchange-unknown -> maximum amount:  145.0 BTC ($ 5832309.0) USD - date: 2022-04-22 19:37:11)
# txo: unknown-exchange -> maximum amount:  44.014 BTC ($ 1745885.1) USD - date: 2022-04-22 13:48:09)

# %%
#import os
#from whalealert.whalealert import WhaleAlert
#import time
#
#whale = WhaleAlert()

# %%
#api_key = os.environ['api_key_whale']
#transaction_count_limit = 1
#start_time = int(time.time() - 600)
#success, transactions, status = whale.get_transactions(start_time, api_key=api_key, limit=transaction_count_limit)
#transactions
