# %%
import pandas as pd

# %%
database_txo = pd.read_csv('../dataset/database_txo_btc.csv')
database_txo
# Out:
#    blockchain  amount_coin   amount_usd  \
# 0         BTC    20.473404    839606.40
# 1         BTC    79.055360   3288277.20
# 2         BTC    14.521699    598052.90
# 3         BTC   112.558770   4632637.50
# 4         BTC    60.503838   2485197.00
# 5         BTC    20.762096    848476.00
# 6         BTC    15.590613    636049.06
# 7         BTC    26.209835   1064864.10
# 8         BTC   265.753300  10842239.00
# 9         BTC    40.077380   1635082.50
# 10        BTC    16.592272    672580.80
# 11        BTC    18.438608    752718.56
# 12        BTC    30.483969   1237783.50
# 13        BTC   193.413710   7853449.00
# 14        BTC    49.947860   2036507.40
# 15        BTC    57.329132   2319090.80
# 16        BTC    68.044495   2791231.50
# 17        BTC    56.844223   2309036.20
# 18        BTC    15.924728    644178.94
# 19        BTC    56.818928   2298410.00
# 20        BTC    56.794243   2311111.50
#
#                                                  hash            from_to  \
# 0                                     Multiple Hashes    unknown-unknown
# 1   ad8c99df67e330144f7837c508038dd771a009549c3ce6...    unknown-unknown
# 2                                     Multiple Hashes    unknown-unknown
# 3   a633738c8bf6760d069d9b08dcbcdd5454a575cbffe439...    unknown-unknown
# 4   aa02b223d3876c4413c1b3b013ca2e9c36cae2e08ab1a6...    unknown-unknown
# 5                                     Multiple Hashes    unknown-unknown
# 6                                     Multiple Hashes    unknown-unknown
# 7   06c1227771be1660b494f834420c1300d072c709a19b25...  exchange-exchange
# 8   9f32e72b1ed9d2d54783f5d7bd66797a085465dbfb5d4d...                NaN
# 9   9ad6951291b4c7d41b50de12f543b0ab1eecc86a730579...   unknown-exchange
# 10                                    Multiple Hashes    unknown-unknown
# 11  d7aef481699467d08421d99fc84006041cc58b8e7b43e4...  exchange-exchange
# 12                                    Multiple Hashes    unknown-unknown
# 13  2c9ffe9dc2d41bb57b28721a03c43235012d373a2c0de6...    unknown-unknown
# 14  f1f9f95cfb7b4e3fb3cac515a15382598d5f97c5676022...    unknown-unknown
# 15  d820ed5dc96958235a08226d83bf44dd7b177c7fcf1d00...    unknown-unknown
# 16  941dd2ce649d3aafb56dd38fa324243a041a7b2f82bbd8...  exchange-exchange
# 17  ec8823d469aab21d952845926c95319244abb8b502a8e5...    unknown-unknown
# 18                                    Multiple Hashes    unknown-unknown
# 19  67c5adec82cd1576c525d101b4d3b9e775f813d33cd8d4...    unknown-unknown
# 20  4beacffe5fab4729e1be21d826f72ad3bd0512acd5b235...    unknown-unknown
#
#               id                 date     price  change24h_pct
# 0   1.831826e+09  2022-04-21 16:56:00  41245.08           0.17
# 1   1.831827e+09  2022-04-21 16:59:39  41235.97          -0.07
# 2   1.831831e+09  2022-04-21 17:09:00  41210.20           0.08
# 3   1.831835e+09  2022-04-21 17:23:32  41156.12          -0.20
# 4   1.831837e+09  2022-04-21 17:34:09  40759.66          -1.33
# 5   1.831845e+09  2022-04-21 17:44:00  40750.79          -1.42
# 6   1.831847e+09  2022-04-21 17:51:00  40641.38          -1.91
# 7   1.831847e+09  2022-04-21 17:55:12  40647.16          -1.85
# 8            NaN                  NaN       NaN            NaN
# 9   1.831848e+09  2022-04-21 17:57:07  40655.60          -1.81
# 10  1.831851e+09  2022-04-21 18:05:00  40777.81          -1.52
# 11  1.831851e+09  2022-04-21 18:11:06  40782.06          -1.58
# 12  1.831857e+09  2022-04-21 18:32:00  40819.38          -1.57
# 13  1.831855e+09  2022-04-21 18:32:58  40807.83          -1.62
# 14  1.831858e+09  2022-04-21 18:37:25  40821.52          -1.49
# 15  1.831859e+09  2022-04-21 18:41:43  40749.44          -1.79
# 16  1.831860e+09  2022-04-21 18:46:04  40736.36          -1.86
# 17  1.831864e+09  2022-04-21 19:05:35  40755.27          -1.86
# 18  1.831869e+09  2022-04-21 19:15:00  40766.67          -2.06
# 19  1.831867e+09  2022-04-21 19:15:19  40751.61          -2.00
# 20  1.831869e+09  2022-04-21 19:22:31  40312.85          -2.92

# %%
# Looking for NaN on the dataset.
# counting the number of NaN for each feature.
database_txo.isna().sum()
# Out:
# blockchain       0
# amount_coin      0
# amount_usd       0
# hash             0
# from_to          1
# id               1
# date             1
# price            1
# change24h_pct    1
# dtype: int64

# %%
database_txo =  database_txo.dropna()
database_txo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 0 to 20
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   blockchain     20 non-null     object
#  1   amount_coin    20 non-null     float64
#  2   amount_usd     20 non-null     float64
#  3   hash           20 non-null     object
#  4   from_to        20 non-null     object
#  5   id             20 non-null     float64
#  6   date           20 non-null     object
#  7   price          20 non-null     float64
#  8   change24h_pct  20 non-null     float64
# dtypes: float64(5), object(4)
# memory usage: 1.6+ KB

# %%
database_txo.isna().sum()
# Out:
# blockchain       0
# amount_coin      0
# amount_usd       0
# hash             0
# from_to          0
# id               0
# date             0
# price            0
# change24h_pct    0
# dtype: int64

# %%
database_txo['from_to'] = database_txo['from_to'].astype('string')
database_txo['blockchain'] = database_txo['blockchain'].astype('string')
database_txo['hash'] = database_txo['hash'].astype('string')
database_txo['date'] = database_txo['date'].astype('datetime64[ns]')
# Out:
# /tmp/ipykernel_157475/722664305.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   database_txo['from_to'] = database_txo['from_to'].astype('string')
# /tmp/ipykernel_157475/722664305.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   database_txo['blockchain'] = database_txo['blockchain'].astype('string')
# /tmp/ipykernel_157475/722664305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   database_txo['hash'] = database_txo['hash'].astype('string')
# /tmp/ipykernel_157475/722664305.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   database_txo['date'] = database_txo['date'].astype('datetime64[ns]')

# %%
database_txo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 0 to 20
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   blockchain     20 non-null     string
#  1   amount_coin    20 non-null     float64
#  2   amount_usd     20 non-null     float64
#  3   hash           20 non-null     string
#  4   from_to        20 non-null     string
#  5   id             20 non-null     float64
#  6   date           20 non-null     datetime64[ns]
#  7   price          20 non-null     float64
#  8   change24h_pct  20 non-null     float64
# dtypes: datetime64[ns](1), float64(5), string(3)
# memory usage: 1.6 KB

# %%
df_amount_usd_fromto = database_txo.drop(columns=['blockchain','hash','id'])
df_amount_usd_fromto
# Out:
#     amount_coin  amount_usd            from_to                date     price  \
# 0     20.473404   839606.40    unknown-unknown 2022-04-21 16:56:00  41245.08
# 1     79.055360  3288277.20    unknown-unknown 2022-04-21 16:59:39  41235.97
# 2     14.521699   598052.90    unknown-unknown 2022-04-21 17:09:00  41210.20
# 3    112.558770  4632637.50    unknown-unknown 2022-04-21 17:23:32  41156.12
# 4     60.503838  2485197.00    unknown-unknown 2022-04-21 17:34:09  40759.66
# 5     20.762096   848476.00    unknown-unknown 2022-04-21 17:44:00  40750.79
# 6     15.590613   636049.06    unknown-unknown 2022-04-21 17:51:00  40641.38
# 7     26.209835  1064864.10  exchange-exchange 2022-04-21 17:55:12  40647.16
# 9     40.077380  1635082.50   unknown-exchange 2022-04-21 17:57:07  40655.60
# 10    16.592272   672580.80    unknown-unknown 2022-04-21 18:05:00  40777.81
# 11    18.438608   752718.56  exchange-exchange 2022-04-21 18:11:06  40782.06
# 12    30.483969  1237783.50    unknown-unknown 2022-04-21 18:32:00  40819.38
# 13   193.413710  7853449.00    unknown-unknown 2022-04-21 18:32:58  40807.83
# 14    49.947860  2036507.40    unknown-unknown 2022-04-21 18:37:25  40821.52
# 15    57.329132  2319090.80    unknown-unknown 2022-04-21 18:41:43  40749.44
# 16    68.044495  2791231.50  exchange-exchange 2022-04-21 18:46:04  40736.36
# 17    56.844223  2309036.20    unknown-unknown 2022-04-21 19:05:35  40755.27
# 18    15.924728   644178.94    unknown-unknown 2022-04-21 19:15:00  40766.67
# 19    56.818928  2298410.00    unknown-unknown 2022-04-21 19:15:19  40751.61
# 20    56.794243  2311111.50    unknown-unknown 2022-04-21 19:22:31  40312.85
#
#     change24h_pct
# 0            0.17
# 1           -0.07
# 2            0.08
# 3           -0.20
# 4           -1.33
# 5           -1.42
# 6           -1.91
# 7           -1.85
# 9           -1.81
# 10          -1.52
# 11          -1.58
# 12          -1.57
# 13          -1.62
# 14          -1.49
# 15          -1.79
# 16          -1.86
# 17          -1.86
# 18          -2.06
# 19          -2.00
# 20          -2.92

# %%
from_tos = list(df_amount_usd_fromto['from_to'].unique())

for ifrom_to in from_tos:
    df_amount_coin = df_amount_usd_fromto[['amount_coin','date']].loc[df_amount_usd_fromto['from_to'] == f'{ifrom_to}']
    df_amount_usd = df_amount_usd_fromto[['amount_usd','date']].loc[df_amount_usd_fromto['from_to'] == f'{ifrom_to}']
    amount_coin = dict(df_amount_coin.max())
    amount_usd = dict(df_amount_usd.max())
    coins = amount_coin['amount_coin']
    txo_coins_date = amount_coin['date']
    usds = amount_usd['amount_usd']
    print(f'txo: {ifrom_to} -> maximum amount:  {coins} BTC ($ {usds}) USD - date: {txo_coins_date})')
# Out:
# txo: unknown-unknown -> maximum amount:  193.41371 BTC ($ 7853449.0) USD - date: 2022-04-21 19:22:31)
# txo: exchange-exchange -> maximum amount:  68.044495 BTC ($ 2791231.5) USD - date: 2022-04-21 18:46:04)
# txo: unknown-exchange -> maximum amount:  40.07738 BTC ($ 1635082.5) USD - date: 2022-04-21 17:57:07)

# %%
import os
from whalealert.whalealert import WhaleAlert
import time

whale = WhaleAlert()

# %%
api_key = os.environ['api_key_whale']
transaction_count_limit = 1
start_time = int(time.time() - 600)
success, transactions, status = whale.get_transactions(start_time, api_key=api_key, limit=transaction_count_limit)
transactions
# Out:
# [{'blockchain': 'ethereum',
#   'symbol': 'USDT',
#   'id': '1831872750',
#   'transaction_type': 'transfer',
#   'hash': '53a21253091e772bbc8813f7c3e2d3ad1885e60acf36241755f576558484527b',
#   'from': {'address': '5bd9dee999fe2c4e6efdbab2c395b4685b0c00d0',
#    'owner_type': 'unknown',
#    'owner': ''},
#   'to': {'address': '4beb757acf8a3727f51d9ebe5892569ebd2f0838',
#    'owner': 'ftx',
#    'owner_type': 'exchange'},
#   'timestamp': 1650580185,
#   'amount': 866938.75,
#   'amount_usd': 866938.75,
#   'transaction_count': 1}]
